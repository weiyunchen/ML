# %%
import numpy as np
import jieba
import jieba.analyse
from os import path 
from PIL import Image
from wordcloud import WordCloud

# %%
path0 = '贝壳.txt'
file_in = open(path0, 'r',encoding='utf-8')
content = file_in.read()
try:
    jieba.analyse.set_stop_words('stopwords.txt')
    tags = jieba.analyse.extract_tags(content, topK=500, withWeight=True, allowPOS=('a', 'vn','n'))
    for v,n in tags:
        out_words=v
        with open('cipin.txt','a+',encoding='utf-8')as f:
            f.write(out_words+'\n')
finally:
    file_in.close()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.561 seconds.
# Prefix dict has been built succesfully.

# %%
mask=np.array(Image.open("dipian.png"))
wcd=WordCloud(background_color=None,repeat=True,max_words=500,height=480,width=854,
             max_font_size=100,font_path="msyh.ttc",colormap="Blues",mask=mask,
             mode="RGBA")

# %%
text_path="cipin.txt"
text=open(path.join(text_path),encoding="utf8").read()

# %%
yun=" ".join(jieba.lcut(text))

# %%
wcd.generate(yun)

# %%
wcd.to_image()
# Out:
# <PIL.Image.Image image mode=RGBA size=2077x1654 at 0x7F759AEFF278>

# %%
wcd.to_file("beike.png")
